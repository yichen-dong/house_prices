# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns',100)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import cross_validate, GridSearchCV

# %%
import statsmodels.api as sm

# %%
from sklearn.pipeline import make_pipeline

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
from sklearn.model_selection import cross_validate

# %%
df_raw = pd.read_csv('train.csv')

# %% [markdown]
# Notes:
# - Year Sold and Built not useful by itself, need to be changed into Age at Sale
# - Year Sold minus Year Remodel gives time since last remodel
# - MSSubClass will need some encoding (one-hot)
# - MSZoning will need encoding
# - Street can be one hot encoded
# - Alley will be encoded
# - LotShape encoded
# - LandContour encoded
# - Utilities encode

# %% [markdown]
# ## Data Transforms

# %%
df = df_raw.copy()

# %%
df['AgeHouseAtSale'] = df['YrSold'] - df['YearBuilt']

df['YearsLastRemodelAtSale']  = df['YrSold'] - df['YearRemodAdd']

df['YearsGarageBuiltAtSale'] = df['YrSold'] - df['GarageYrBlt'] 

df.drop(columns=['Id'],inplace=True)

df['MSSubClass'] = df['MSSubClass'].astype(str)

# %%
df['YearsLastRemodelAtSale'] = np.maximum(df['YearsLastRemodelAtSale'],0)

# %%
for var in df.dtypes[df.dtypes == 'int64'].index:
    if df[var].isnull().sum()>0:
        df[var+'_isnull'] = df[var].isnull().astype(int)
        df[var]=df[var].fillna(df[var].mean())

for var in df.dtypes[df.dtypes == 'float64'].index:
    if df[var].isnull().sum()>0:
        df[var+'_isnull'] = df[var].isnull().astype(int)
        df[var]=df[var].fillna(df[var].mean())

df_dummies = pd.get_dummies(df,dummy_na=True,drop_first=False)

# %%
df_dummies.drop(columns=df_dummies.loc[:,df_dummies.nunique() == 1].columns, inplace=True)

# %%
X = df_dummies.drop(columns='SalePrice')

y = np.log(df_dummies['SalePrice'])

X['intercept'] = 1

# %% [markdown]
# ## Looking at effects of Robust Scaler
# Not a huge fan, less explainable and causes convergence issues for Lasso

# %%
standardscaler = RobustScaler()

# %%
standardscaler.fit(X)
# Out:
# RobustScaler()

# %%
test = standardscaler.transform(X)

# %%
test = pd.DataFrame(test,columns=X.columns)

# %%
test.describe()
# Out:
#         LotFrontage      LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1.460000e+03  1460.000000  1460.000000  1460.000000  1460.000000
# mean  -3.023076e-16     0.256504     0.049658     0.575342    -0.037656
# std    1.159159e+00     2.465728     0.691498     1.112799     0.656585
# min   -2.581577e+00    -2.020380    -2.500000    -4.000000    -2.195652
# 25%   -5.289452e-01    -0.475543    -0.500000     0.000000    -0.413043
# 50%    0.000000e+00     0.000000     0.000000     0.000000     0.000000
# 75%    4.710548e-01     0.524457     0.500000     1.000000     0.586957
# max    1.278684e+01    50.831645     2.000000     4.000000     0.804348
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  \
# count   1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      -0.246872     0.631265     0.084436    46.549315     0.153402
# std        0.557984     1.099355     0.640362   161.319273     0.755328
# min       -1.189189     0.000000    -0.538435     0.000000    -0.816239
# 25%       -0.729730     0.000000    -0.538435     0.000000    -0.435043
# 50%        0.000000     0.000000     0.000000     0.000000     0.000000
# 75%        0.270270     1.000000     0.461565     0.000000     0.564957
# max        0.432432     9.741248     7.385749  1474.000000     3.176923
#
#        TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean      0.131203     0.148506     0.476638      5.844521     0.079511
# std       0.873045     0.759132     0.599627     48.623081     0.811866
# min      -1.973134    -1.478645     0.000000      0.000000    -1.745848
# 25%      -0.389552    -0.402553     0.000000      0.000000    -0.516802
# 50%       0.000000     0.000000     0.000000      0.000000     0.000000
# 75%       0.610448     0.597447     1.000000      0.000000     0.483198
# max      10.186070     7.079038     2.836538    572.000000     6.455002
#
#        BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  BedroomAbvGr  \
# count   1460.000000   1460.000000  1460.000000  1460.000000   1460.000000
# mean       0.425342      0.057534    -0.434932     0.382877     -0.133562
# std        0.518911      0.238753     0.550916     0.502885      0.815778
# min        0.000000      0.000000    -2.000000     0.000000     -3.000000
# 25%        0.000000      0.000000    -1.000000     0.000000     -1.000000
# 50%        0.000000      0.000000     0.000000     0.000000      0.000000
# 75%        1.000000      0.000000     0.000000     1.000000      0.000000
# max        3.000000      2.000000     1.000000     2.000000      5.000000
#
#        KitchenAbvGr  TotRmsAbvGrd   Fireplaces   GarageYrBlt   GarageCars  \
# count   1460.000000   1460.000000  1460.000000  1.460000e+03  1460.000000
# mean       0.046575      0.258904    -0.386986  2.405382e-15    -0.232877
# std        0.220338      0.812697     0.644666  6.152457e-01     0.747315
# min       -1.000000     -2.000000    -1.000000 -2.012979e+00    -2.000000
# 25%        0.000000     -0.500000    -1.000000 -4.232350e-01    -1.000000
# 50%        0.000000      0.000000     0.000000  0.000000e+00     0.000000
# 75%        0.000000      0.500000     0.000000  5.767650e-01     0.000000
# max        2.000000      4.000000     2.000000  8.075343e-01     2.000000
#
#         GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean     -0.029068     0.560979     0.318533      21.954110     3.409589
# std       0.885320     0.746064     0.974353      61.119149    29.317331
# min      -1.987578     0.000000    -0.367647       0.000000     0.000000
# 25%      -0.602484     0.000000    -0.367647       0.000000     0.000000
# 50%       0.000000     0.000000     0.000000       0.000000     0.000000
# 75%       0.397516     1.000000     0.632353       0.000000     0.000000
# max       3.884058     5.101190     7.676471     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     0.107306    -0.092123
# std      55.757415    40.177307    496.123024     0.901209     0.664048
# min       0.000000     0.000000      0.000000    -1.666667    -1.000000
# 25%       0.000000     0.000000      0.000000    -0.333333    -0.500000
# 50%       0.000000     0.000000      0.000000     0.000000     0.000000
# 75%       0.000000     0.000000      0.000000     0.666667     0.500000
# max     480.000000   738.000000  15500.000000     2.000000     1.000000
#
#        AgeHouseAtSale  YearsLastRemodelAtSale  YearsGarageBuiltAtSale  \
# count     1460.000000             1460.000000            1.460000e+03
# mean         0.033651                0.241892            9.923569e-18
# std          0.657612                0.557855            6.161716e-01
# min         -0.760870               -0.405405           -7.514364e-01
# 25%         -0.586957               -0.270270           -5.719492e-01
# 50%          0.000000                0.000000            0.000000e+00
# 75%          0.413043                0.729730            4.280508e-01
# max          2.195652                1.243243            1.992153e+00
#
#        LotFrontage_isnull  MasVnrArea_isnull  GarageYrBlt_isnull  \
# count         1460.000000        1460.000000         1460.000000
# mean             0.177397           0.005479            0.055479
# std              0.382135           0.073846            0.228992
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# 50%              0.000000           0.000000            0.000000
# 75%              0.000000           0.000000            0.000000
# max              1.000000           1.000000            1.000000
#
#        YearsGarageBuiltAtSale_isnull  MSSubClass_120  MSSubClass_160  \
# count                    1460.000000     1460.000000     1460.000000
# mean                        0.055479        0.059589        0.043151
# std                         0.228992        0.236805        0.203266
# min                         0.000000        0.000000        0.000000
# 25%                         0.000000        0.000000        0.000000
# 50%                         0.000000        0.000000        0.000000
# 75%                         0.000000        0.000000        0.000000
# max                         1.000000        1.000000        1.000000
#
#        MSSubClass_180  MSSubClass_190  MSSubClass_20  MSSubClass_30  \
# count     1460.000000     1460.000000    1460.000000    1460.000000
# mean         0.006849        0.020548       0.367123       0.047260
# std          0.082505        0.141914       0.482186       0.212268
# min          0.000000        0.000000       0.000000       0.000000
# 25%          0.000000        0.000000       0.000000       0.000000
# 50%          0.000000        0.000000       0.000000       0.000000
# 75%          0.000000        0.000000       1.000000       0.000000
# max          1.000000        1.000000       1.000000       1.000000
#
#        MSSubClass_40  MSSubClass_45  ...  GarageFinish_Unf  GarageFinish_nan  \
# count    1460.000000    1460.000000  ...       1460.000000       1460.000000
# mean        0.002740       0.008219  ...          0.414384          0.055479
# std         0.052289       0.090317  ...          0.492784          0.228992
# min         0.000000       0.000000  ...          0.000000          0.000000
# 25%         0.000000       0.000000  ...          0.000000          0.000000
# 50%         0.000000       0.000000  ...          0.000000          0.000000
# 75%         0.000000       0.000000  ...          1.000000          0.000000
# max         1.000000       1.000000  ...          1.000000          1.000000
#
#        GarageQual_Ex  GarageQual_Fa  GarageQual_Gd  GarageQual_Po  \
# count    1460.000000    1460.000000    1460.000000    1460.000000
# mean        0.002055       0.032877       0.009589       0.002055
# std         0.045299       0.178375       0.097486       0.045299
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        GarageQual_TA  GarageQual_nan  GarageCond_Ex  GarageCond_Fa  \
# count    1460.000000     1460.000000    1460.000000    1460.000000
# mean       -0.102055        0.055479       0.001370       0.023973
# std         0.302824        0.228992       0.036999       0.153016
# min        -1.000000        0.000000       0.000000       0.000000
# 25%         0.000000        0.000000       0.000000       0.000000
# 50%         0.000000        0.000000       0.000000       0.000000
# 75%         0.000000        0.000000       0.000000       0.000000
# max         0.000000        1.000000       1.000000       1.000000
#
#        GarageCond_Gd  GarageCond_Po  GarageCond_TA  GarageCond_nan  \
# count    1460.000000    1460.000000    1460.000000     1460.000000
# mean        0.006164       0.004795      -0.091781        0.055479
# std         0.078298       0.069100       0.288815        0.228992
# min         0.000000       0.000000      -1.000000        0.000000
# 25%         0.000000       0.000000       0.000000        0.000000
# 50%         0.000000       0.000000       0.000000        0.000000
# 75%         0.000000       0.000000       0.000000        0.000000
# max         1.000000       1.000000       0.000000        1.000000
#
#        PavedDrive_N  PavedDrive_P  PavedDrive_Y  PavedDrive_nan    PoolQC_Ex  \
# count   1460.000000   1460.000000   1460.000000          1460.0  1460.000000
# mean       0.061644      0.020548     -0.082192             0.0     0.001370
# std        0.240590      0.141914      0.274751             0.0     0.036999
# min        0.000000      0.000000     -1.000000             0.0     0.000000
# 25%        0.000000      0.000000      0.000000             0.0     0.000000
# 50%        0.000000      0.000000      0.000000             0.0     0.000000
# 75%        0.000000      0.000000      0.000000             0.0     0.000000
# max        1.000000      1.000000      0.000000             0.0     1.000000
#
#          PoolQC_Fa    PoolQC_Gd   PoolQC_nan  Fence_GdPrv   Fence_GdWo  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      0.001370     0.002055    -0.004795     0.040411     0.036986
# std       0.036999     0.045299     0.069100     0.196989     0.188793
# min       0.000000     0.000000    -1.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     0.000000     1.000000     1.000000
#
#        Fence_MnPrv   Fence_MnWw    Fence_nan  MiscFeature_Gar2  \
# count  1460.000000  1460.000000  1460.000000       1460.000000
# mean      0.107534     0.007534    -0.192466          0.001370
# std       0.309897     0.086502     0.394372          0.036999
# min       0.000000     0.000000    -1.000000          0.000000
# 25%       0.000000     0.000000     0.000000          0.000000
# 50%       0.000000     0.000000     0.000000          0.000000
# 75%       0.000000     0.000000     0.000000          0.000000
# max       1.000000     1.000000     0.000000          1.000000
#
#        MiscFeature_Othr  MiscFeature_Shed  MiscFeature_TenC  MiscFeature_nan  \
# count       1460.000000       1460.000000       1460.000000      1460.000000
# mean           0.001370          0.033562          0.000685        -0.036986
# std            0.036999          0.180160          0.026171         0.188793
# min            0.000000          0.000000          0.000000        -1.000000
# 25%            0.000000          0.000000          0.000000         0.000000
# 50%            0.000000          0.000000          0.000000         0.000000
# 75%            0.000000          0.000000          0.000000         0.000000
# max            1.000000          1.000000          1.000000         0.000000
#
#        SaleType_COD  SaleType_CWD  SaleType_Con  SaleType_ConLD  \
# count   1460.000000   1460.000000   1460.000000     1460.000000
# mean       0.029452      0.002740      0.001370        0.006164
# std        0.169128      0.052289      0.036999        0.078298
# min        0.000000      0.000000      0.000000        0.000000
# 25%        0.000000      0.000000      0.000000        0.000000
# 50%        0.000000      0.000000      0.000000        0.000000
# 75%        0.000000      0.000000      0.000000        0.000000
# max        1.000000      1.000000      1.000000        1.000000
#
#        SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  \
# count     1460.000000     1460.000000   1460.000000   1460.000000
# mean         0.003425        0.003425      0.083562      0.002055
# std          0.058440        0.058440      0.276824      0.045299
# min          0.000000        0.000000      0.000000      0.000000
# 25%          0.000000        0.000000      0.000000      0.000000
# 50%          0.000000        0.000000      0.000000      0.000000
# 75%          0.000000        0.000000      0.000000      0.000000
# max          1.000000        1.000000      1.000000      1.000000
#
#        SaleType_WD  SaleType_nan  SaleCondition_Abnorml  \
# count  1460.000000        1460.0            1460.000000
# mean     -0.132192           0.0               0.069178
# std       0.338815           0.0               0.253844
# min      -1.000000           0.0               0.000000
# 25%       0.000000           0.0               0.000000
# 50%       0.000000           0.0               0.000000
# 75%       0.000000           0.0               0.000000
# max       0.000000           0.0               1.000000
#
#        SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# count            1460.000000           1460.000000           1460.000000
# mean                0.002740              0.008219              0.013699
# std                 0.052289              0.090317              0.116277
# min                 0.000000              0.000000              0.000000
# 25%                 0.000000              0.000000              0.000000
# 50%                 0.000000              0.000000              0.000000
# 75%                 0.000000              0.000000              0.000000
# max                 1.000000              1.000000              1.000000
#
#        SaleCondition_Normal  SaleCondition_Partial  SaleCondition_nan  \
# count           1460.000000            1460.000000             1460.0
# mean              -0.179452               0.085616                0.0
# std                0.383862               0.279893                0.0
# min               -1.000000               0.000000                0.0
# 25%                0.000000               0.000000                0.0
# 50%                0.000000               0.000000                0.0
# 75%                0.000000               0.000000                0.0
# max                0.000000               1.000000                0.0
#
#        intercept
# count     1460.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
#
# [8 rows x 354 columns]

# %% [markdown]
# ## Creating own scaler
#
# Based on taking the log first (adding a 1 so that 0s become 1s), and then centering and dividing out the standard deviation
#
# The log standard is incredibly promising for Elastic Net. In fact, it's almost the best performing model yet (only beaten by the stacking regression)
#
# Bayesian Ridge also showed improvement

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class LogStandardScaler(BaseEstimator, TransformerMixin):
    def __init__(self): # no *args or **kargs
        self.init = True
    def fit(self, X, y=None):
        return self  # nothing else to do
    def transform(self, X, y=None):
        temp = np.log(X+1)
        X_scaled = (temp - temp.mean())/temp.std()
        return X_scaled.fillna(0)

# %%
test_scaler = LogStandardScaler()

# %%
test_scaler.fit(X)
# Out:
# LogStandardScaler()

# %%
test_scaler.transform(X).describe()
# Out:
#         LotFrontage       LotArea   OverallQual   OverallCond     YearBuilt  \
# count  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03
# mean   2.380900e-14  4.933401e-15 -6.560004e-14 -4.113521e-14 -9.143495e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.577797e+00 -3.749892e+00 -6.174595e+00 -6.984065e+00 -3.348087e+00
# 25%   -3.374865e-01 -3.499788e-01 -7.354547e-01 -4.602502e-01 -5.637630e-01
# 50%    1.470817e-01  8.875776e-02  2.773275e-02 -4.602502e-01  6.470948e-02
# 75%    5.240474e-01  4.793668e-01  6.888358e-01  4.551323e-01  9.474735e-01
# max    4.868581e+00  6.124392e+00  2.265474e+00  2.573151e+00  1.271404e+00
#
#        YearRemodAdd    MasVnrArea    BsmtFinSF1    BsmtFinSF2     BsmtUnfSF  \
# count  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03
# mean   2.242042e-14 -8.323631e-16  1.150678e-15  1.289684e-16  2.523058e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.694032e+00 -8.156799e-01 -1.413655e+00 -3.552207e-01 -3.046557e+00
# 25%   -8.617529e-01 -8.156799e-01 -1.413655e+00 -3.552207e-01 -1.276856e-01
# 50%    4.454383e-01 -8.156799e-01  5.755955e-01 -3.552207e-01  2.816979e-01
# 75%    9.250985e-01  1.125857e+00  7.821056e-01 -3.552207e-01  5.649459e-01
# max    1.211748e+00  1.989122e+00  1.473502e+00  3.599379e+00  1.137121e+00
#
#         TotalBsmtSF      1stFlrSF      2ndFlrSF  LowQualFinSF     GrLivArea  \
# count  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03
# mean  -4.532105e-15 -3.216035e-14  1.963422e-16 -1.847457e-16 -1.521705e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -5.892019e+00 -3.762460e+00 -8.698193e-01 -1.335566e-01 -4.363541e+00
# 25%   -6.111400e-02 -7.092162e-01 -8.698193e-01 -1.335566e-01 -7.143553e-01
# 50%    1.306323e-01 -5.152768e-02 -8.698193e-01 -1.335566e-01  6.330204e-02
# 75%    3.656961e-01  7.252719e-01  1.131714e+00 -1.335566e-01  6.438339e-01
# max    1.717085e+00  4.553349e+00  1.448021e+00  8.364276e+00  4.109352e+00
#
#        BsmtFullBath  BsmtHalfBath      FullBath      HalfBath  BedroomAbvGr  \
# count  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03
# mean  -1.687539e-15  1.558495e-16 -8.796312e-15 -1.612409e-15  9.896041e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -8.329399e-01 -2.428400e-01 -4.110643e+00 -7.693754e-01 -5.775990e+00
# 25%   -8.329399e-01 -2.428400e-01 -1.006267e+00 -7.693754e-01 -9.974921e-01
# 50%   -8.329399e-01 -2.428400e-01  8.096768e-01 -7.693754e-01  2.538029e-01
# 75%    1.148394e+00 -2.428400e-01  8.096768e-01  1.258149e+00  2.538029e-01
# max    3.129729e+00  6.513721e+00  2.098109e+00  2.444175e+00  3.781005e+00
#
#        KitchenAbvGr  TotRmsAbvGrd    Fireplaces   GarageYrBlt    GarageCars  \
# count  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03
# mean   2.716214e-13 -6.905834e-14  4.611836e-15 -7.393054e-13 -2.324077e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -7.972346e+00 -4.181158e+00 -1.013214e+00 -3.318435e+00 -3.017973e+00
# 25%   -2.075362e-01 -9.458646e-01 -1.013214e+00 -6.818393e-01 -8.671381e-01
# 50%   -2.075362e-01 -2.263599e-01  7.431010e-01  6.064994e-03  3.910196e-01
# 75%   -2.075362e-01  3.969034e-01  7.431010e-01  9.343310e-01  3.910196e-01
# max    7.557274e+00  3.330960e+00  2.499416e+00  1.302821e+00  1.976111e+00
#
#          GarageArea    WoodDeckSF   OpenPorchSF  EnclosedPorch     3SsnPorch  \
# count  1.460000e+03  1.460000e+03  1.460000e+03   1.460000e+03  1.460000e+03
# mean   5.914067e-15  1.171513e-15 -1.297060e-15  -1.307554e-16 -2.865288e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
# min   -3.991535e+00 -9.463772e-01 -1.072549e+00  -4.041057e-01 -1.284774e-01
# 25%    5.110200e-03 -9.463772e-01 -1.072549e+00  -4.041057e-01 -1.284774e-01
# 50%    2.527021e-01 -9.463772e-01  4.411640e-01  -4.041057e-01 -1.284774e-01
# 75%    3.777606e-01  1.029370e+00  8.946186e-01  -4.041057e-01 -1.284774e-01
# max    9.961745e-01  1.655115e+00  1.857349e+00   3.252061e+00  9.217257e+00
#
#         ScreenPorch      PoolArea       MiscVal        MoSold        YrSold  \
# count  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03
# mean   4.486518e-18  9.509707e-16  3.201397e-16 -3.141897e-14  1.023335e-11
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.926691e-01 -6.936881e-02 -1.904162e-01 -2.861496e+00 -1.367517e+00
# 25%   -2.926691e-01 -6.936881e-02 -1.904162e-01 -2.798051e-01 -6.140419e-01
# 50%   -2.926691e-01 -6.936881e-02 -1.904162e-01  8.244225e-02  1.390583e-01
# 75%   -2.926691e-01 -6.936881e-02 -1.904162e-01  6.730201e-01  8.917837e-01
# max    4.108624e+00  1.498768e+01  7.679426e+00  1.537157e+00  1.644135e+00
#
#        AgeHouseAtSale  YearsLastRemodelAtSale  YearsGarageBuiltAtSale  \
# count    1.460000e+03            1.460000e+03            1.460000e+03
# mean    -3.168318e-15           -1.922207e-15            7.846843e-16
# std      1.000000e+00            1.000000e+00            1.000000e+00
# min     -2.316576e+00           -1.995653e+00           -2.298676e+00
# 25%     -6.477366e-01           -7.474594e-01           -6.390515e-01
# 50%      4.051836e-01            1.045654e-01            4.239562e-01
# 75%      7.270795e-01            9.030830e-01            7.741682e-01
# max      1.420255e+00            1.192520e+00            1.438183e+00
#
#        LotFrontage_isnull  MasVnrArea_isnull  GarageYrBlt_isnull  \
# count        1.460000e+03       1.460000e+03        1.460000e+03
# mean        -9.236903e-16      -6.872357e-17       -2.002584e-16
# std          1.000000e+00       1.000000e+00        1.000000e+00
# min         -4.642261e-01      -7.420154e-02       -2.422767e-01
# 25%         -4.642261e-01      -7.420154e-02       -2.422767e-01
# 50%         -4.642261e-01      -7.420154e-02       -2.422767e-01
# 75%         -4.642261e-01      -7.420154e-02       -2.422767e-01
# max          2.152647e+00       1.346758e+01        4.124686e+00
#
#        YearsGarageBuiltAtSale_isnull  MSSubClass_120  MSSubClass_160  \
# count                   1.460000e+03     1460.000000     1460.000000
# mean                   -2.002584e-16       -0.000025       -0.000025
# std                     1.000000e+00        1.000039        0.999610
# min                    -2.422767e-01       -0.251673       -0.212229
# 25%                    -2.422767e-01       -0.251673       -0.212229
# 50%                    -2.422767e-01       -0.251673       -0.212229
# 75%                    -2.422767e-01       -0.251673       -0.212229
# max                     4.124686e+00        3.971375        4.705519
#
#        MSSubClass_180  MSSubClass_190  MSSubClass_20  MSSubClass_30  \
# count     1460.000000     1460.000000    1460.000000    1460.000000
# mean        -0.000005        0.000031      -0.000270      -0.000051
# std          1.000273        0.999467       0.999567       0.999735
# min         -0.083044       -0.144684      -0.761314      -0.222637
# 25%         -0.083044       -0.144684      -0.761314      -0.222637
# 50%         -0.083044       -0.144684      -0.761314      -0.222637
# 75%         -0.083044       -0.144684       1.311679      -0.222637
# max         12.040755        6.898094       1.311679       4.487148
#
#        MSSubClass_40  MSSubClass_45  ...  GarageType_nan  GarageFinish_Fin  \
# count    1460.000000    1460.000000  ...     1460.000000       1460.000000
# mean       -0.000003      -0.000005  ...        0.000095          0.000175
# std         0.999997       1.000004  ...        1.000519          0.999360
# min        -0.052399      -0.091009  ...       -0.242308         -0.562911
# 25%        -0.052399      -0.091009  ...       -0.242308         -0.562911
# 50%        -0.052399      -0.091009  ...       -0.242308         -0.562911
# 75%        -0.052399      -0.091009  ...       -0.242308         -0.562911
# max        19.072180      10.981116  ...        4.126923          1.772615
#
#        GarageFinish_RFn  GarageFinish_Unf  GarageFinish_nan  GarageQual_Ex  \
# count       1460.000000       1460.000000       1460.000000    1460.000000
# mean           0.000292         -0.000108          0.000095      -0.000002
# std            0.999892          1.000362          1.000519       1.000183
# min           -0.637034         -0.841315         -0.242308      -0.045372
# 25%           -0.637034         -0.841315         -0.242308      -0.045372
# 50%           -0.637034         -0.841315         -0.242308      -0.045372
# 75%            1.567935          1.188706         -0.242308      -0.045372
# max            1.567935          1.188706          4.126923      22.034317
#
#        GarageQual_Fa  GarageQual_Gd  GarageQual_Po  GarageQual_TA  \
# count    1460.000000    1460.000000    1460.000000    1460.000000
# mean       -0.000010       0.000051      -0.000002       0.000191
# std         1.000168       1.000403       1.000183       1.000024
# min        -0.184353      -0.098351      -0.045372      -2.965116
# 25%        -0.184353      -0.098351      -0.045372       0.337209
# 50%        -0.184353      -0.098351      -0.045372       0.337209
# 75%        -0.184353      -0.098351      -0.045372       0.337209
# max         5.422754      10.163618      22.034317       0.337209
#
#        GarageQual_nan  GarageCond_Ex  GarageCond_Fa  GarageCond_Gd  \
# count     1460.000000    1460.000000    1460.000000    1460.000000
# mean         0.000095      -0.000002       0.000045      -0.000039
# std          1.000519       0.999544       1.000152       1.000524
# min         -0.242308      -0.037010      -0.156646      -0.078810
# 25%         -0.242308      -0.037010      -0.156646      -0.078810
# 50%         -0.242308      -0.037010      -0.156646      -0.078810
# 75%         -0.242308      -0.037010      -0.156646      -0.078810
# max          4.126923      26.978448       6.379603      12.699592
#
#        GarageCond_Po  GarageCond_TA  GarageCond_nan  PavedDrive_N  \
# count    1460.000000    1460.000000     1460.000000   1460.000000
# mean        0.000036      -0.000802        0.000095     -0.000083
# std         0.999969       1.000287        1.000519      1.000403
# min        -0.069347      -3.146341       -0.242308     -0.256406
# 25%        -0.069347       0.317073       -0.242308     -0.256406
# 50%        -0.069347       0.317073       -0.242308     -0.256406
# 75%        -0.069347       0.317073       -0.242308     -0.256406
# max        14.401990       0.317073        4.126923      3.901720
#
#        PavedDrive_P  PavedDrive_Y    PoolQC_Ex    PoolQC_Fa    PoolQC_Gd  \
# count   1460.000000   1460.000000  1460.000000  1460.000000  1460.000000
# mean       0.000031      0.000738    -0.000002    -0.000002    -0.000002
# std        0.999467      1.000375     0.999544     0.999544     1.000183
# min       -0.144684     -3.341026    -0.037010    -0.037010    -0.045372
# 25%       -0.144684      0.300000    -0.037010    -0.037010    -0.045372
# 50%       -0.144684      0.300000    -0.037010    -0.037010    -0.045372
# 75%       -0.144684      0.300000    -0.037010    -0.037010    -0.045372
# max        6.898094      0.300000    26.978448    26.978448    22.034317
#
#         PoolQC_nan  Fence_GdPrv   Fence_GdWo  Fence_MnPrv   Fence_MnWw  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      0.001954     0.000031     0.000077    -0.000117     0.000027
# std       0.999969     0.999906     0.999388     1.000123     1.000166
# min     -14.400000    -0.205094    -0.195713    -0.347159    -0.087087
# 25%       0.071338    -0.205094    -0.195713    -0.347159    -0.087087
# 50%       0.071338    -0.205094    -0.195713    -0.347159    -0.087087
# 75%       0.071338    -0.205094    -0.195713    -0.347159    -0.087087
# max       0.071338     4.870867     5.097856     2.880114    11.475254
#
#          Fence_nan  MiscFeature_Gar2  MiscFeature_Othr  MiscFeature_Shed  \
# count  1460.000000       1460.000000       1460.000000       1460.000000
# mean     -0.000538         -0.000002         -0.000002          0.000005
# std       1.000015          0.999544          0.999544          1.000300
# min      -2.048214         -0.037010         -0.037010         -0.186339
# 25%       0.487500         -0.037010         -0.037010         -0.186339
# 50%       0.487500         -0.037010         -0.037010         -0.186339
# 75%       0.487500         -0.037010         -0.037010         -0.186339
# max       0.487500         26.978448         26.978448          5.365958
#
#        MiscFeature_TenC  MiscFeature_nan  SaleType_COD  SaleType_CWD  \
# count       1460.000000      1460.000000   1460.000000   1460.000000
# mean          -0.000001        -0.001942      0.000039     -0.000003
# std            1.000184         1.000320      1.000152      0.999997
# min           -0.026177        -5.104478     -0.174128     -0.052399
# 25%           -0.026177         0.194030     -0.174128     -0.052399
# 50%           -0.026177         0.194030     -0.174128     -0.052399
# 75%           -0.026177         0.194030     -0.174128     -0.052399
# max           38.190812         0.194030      5.739459     19.072180
#
#        SaleType_Con  SaleType_ConLD  SaleType_ConLI  SaleType_ConLw  \
# count   1460.000000     1460.000000     1460.000000     1460.000000
# mean      -0.000002       -0.000039       -0.000003       -0.000003
# std        0.999544        1.000524        0.999822        0.999822
# min       -0.037010       -0.078810       -0.058594       -0.058594
# 25%       -0.037010       -0.078810       -0.058594       -0.058594
# 50%       -0.037010       -0.078810       -0.058594       -0.058594
# 75%       -0.037010       -0.078810       -0.058594       -0.058594
# max       26.978448       12.699592       17.049840       17.049840
#
#        SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# count   1460.000000   1460.000000  1460.000000            1460.000000
# mean       0.000083     -0.000002     0.000598               0.000126
# std        1.000230      1.000183     1.000244               0.999884
# min       -0.301845     -0.045372    -2.561331              -0.272365
# 25%       -0.301845     -0.045372     0.390852              -0.272365
# 50%       -0.301845     -0.045372     0.390852              -0.272365
# 75%       -0.301845     -0.045372     0.390852              -0.272365
# max        3.311387     22.034317     0.390852               3.666609
#
#        SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# count            1460.000000           1460.000000           1460.000000
# mean               -0.000003             -0.000005             -0.000006
# std                 0.999997              1.000004              0.999926
# min                -0.052399             -0.091009             -0.117808
# 25%                -0.052399             -0.091009             -0.117808
# 50%                -0.052399             -0.091009             -0.117808
# 75%                -0.052399             -0.091009             -0.117808
# max                19.072180             10.981116              8.481737
#
#        SaleCondition_Normal  SaleCondition_Partial     intercept
# count           1460.000000            1460.000000  1.460000e+03
# mean               0.000327              -0.000125  9.996575e-01
# std                1.000154               1.000497  5.997259e-15
# min               -2.137615              -0.306167  9.996575e-01
# 25%                0.467890              -0.306167  9.996575e-01
# 50%                0.467890              -0.306167  9.996575e-01
# 75%                0.467890              -0.306167  9.996575e-01
# max                0.467890               3.268408  9.996575e-01
#
# [8 rows x 326 columns]

# %% [markdown]
# # Training

# %% [markdown]
# ## SKLEARN

# %%
from sklearn.linear_model import LassoCV

# %%
lasso_cv = LassoCV(cv=5, random_state=0,max_iter=2000)

# %%
lasso_pipeline = make_pipeline(LogStandardScaler(),lasso_cv)

# %%
lasso_pipeline.fit(X=X,y=y)
# Out:
# Pipeline(steps=[('logstandardscaler', LogStandardScaler()),
#                 ('lassocv', LassoCV(cv=5, max_iter=2000, random_state=0))])

# %%
lasso_cv.alpha_
# Out:
# 0.003947179385645563

# %% [raw]
# test = pd.DataFrame(lasso_pipeline.coef_,index=X.columns)
# test.loc[test[0]>0]

# %% [markdown]
# ### Elastic Net
# Looks like the optimal is just an L1 Lasso regression

# %%
from sklearn.linear_model import ElasticNetCV

# %%
# elastic_net_cv = ElasticNetCV(l1_ratio=[0,.5,1]
#                              ,alphas=[0.1,1,10,100]
#                              )
elastic_net_cv = ElasticNetCV(cv=5, random_state=0, l1_ratio=[0.5,0.7,0.8,0.9,1],max_iter=2000)

# %%
elastic_net_pipeline = make_pipeline(LogStandardScaler(),elastic_net_cv)

# %%
elastic_net_pipeline.fit(X=X,y=y)
# Out:
# Pipeline(steps=[('logstandardscaler', LogStandardScaler()),
#                 ('elasticnetcv',
#                  ElasticNetCV(cv=5, l1_ratio=[0.5, 0.7, 0.8, 0.9, 1],
#                               max_iter=2000, random_state=0))])

# %%
elastic_net_cv.l1_ratio_
# Out:
# 0.5

# %%
elastic_net_cv.alpha_
# Out:
# 0.007894358771291127

# %%
test = pd.DataFrame(elastic_net_cv.coef_,index=X.columns)

# %% [raw]
# from sklearn.linear_model import ElasticNet

# %% [raw]
# elastic_net = ElasticNet(l1_ratio=0.9,alpha=1.1391563296792413)

# %% [markdown]
# ### Decision Tree

# %%
params_dt={'splitter':['random', 'best']
        ,'min_samples_split':[2, 3, 4, 5, 6, 8, 10]
        ,'min_samples_leaf':[0.01, 0.02, 0.03, 0.04]
        ,'min_impurity_decrease':[0.0, 0.0005, 0.005, 0.05, 0.10, 0.15, 0.2]
        ,'max_leaf_nodes':[10, 15, 20, 25, 30, 35, 40, 45, 50, None]
        ,'max_features':[ 0.95, 0.90, 0.85, 0.80, 0.75, 0.70]
        ,'max_depth':[None, 2,4,6,8]
        ,'min_weight_fraction_leaf':[0.0, 0.0025, 0.005, 0.0075, 0.01, 0.05]}

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
from skopt import BayesSearchCV

# %%
decision_tree = DecisionTreeRegressor()

# %%
bayes_search_dt = BayesSearchCV(decision_tree,params_dt)

# %% [raw]
# grid_search_dt = RandomizedSearchCV(decision_tree,params_dt,n_jobs=-1,n_iter=100)

# %% [raw]
# bayes_search_dt.fit(X,y)

# %% [raw]
# bayes_search_dt.best_estimator_

# %%
decision_tree = DecisionTreeRegressor(max_depth=6, max_features=0.85, max_leaf_nodes=40,
                      min_samples_leaf=0.02, min_samples_split=6,
                      min_weight_fraction_leaf=0.0075)

# %%
decision_tree_pipeline = make_pipeline(LogStandardScaler(),decision_tree)

# %%
decision_tree_pipeline.fit(X,y)
# Out:
# Pipeline(steps=[('logstandardscaler', LogStandardScaler()),
#                 ('decisiontreeregressor',
#                  DecisionTreeRegressor(max_depth=6, max_features=0.85,
#                                        max_leaf_nodes=40, min_samples_leaf=0.02,
#                                        min_samples_split=6,
#                                        min_weight_fraction_leaf=0.0075))])

# %% [markdown]
# ## XGBoost

# %%
import xgboost

# %%
from importlib import reload

# %%
reload(xgboost)
# Out:
# <module 'xgboost' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\xgboost\\__init__.py'>

# %%
xgboost.__version__
# Out:
# '1.6.2'

# %%
xg_boost = xgboost.XGBRegressor()

# %%
xg_boost_pipeline = make_pipeline(LogStandardScaler(),xg_boost)

# %%
xg_boost_pipeline.fit(X,y)
# Out:
# Pipeline(steps=[('logstandardscaler', LogStandardScaler()),
#                 ('xgbregressor',
#                  XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#                               colsample_bylevel=1, colsample_bynode=1,
#                               colsample_bytree=1, early_stopping_rounds=None,
#                               enable_categorical=False, eval_metric=None,
#                               gamma=0, gpu_id=-1, grow_policy='depthwise',
#                               importance_type=None, interaction_constraints='',
#                               learning_rate=0.300000012, max_bin=256,
#                               max_cat_to_onehot=4, max_delta_step=0,
#                               max_depth=6, max_leaves=0, min_child_weight=1,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#                               predictor='auto', random_state=0, reg_alpha=0,
#                               reg_lambda=1, ...))])

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random_forest_initial = RandomForestRegressor(n_estimators=200,oob_score=True)

# %%
random_forest_pipeline = make_pipeline(LogStandardScaler(),random_forest_initial)

# %%
random_forest_pipeline.fit(X,y)
# Out:
# Pipeline(steps=[('logstandardscaler', LogStandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(n_estimators=200, oob_score=True))])

# %% [raw]
# random_forest.oob_score_

# %% [raw]
# oob_scores = {}
# rf = RandomForestRegressor(n_estimators=50, warm_start=True, oob_score=True, n_jobs=-1, random_state=2)
# rf.fit(X, y)
# oob_scores[50] = rf.oob_score_
# est = 50
# estimators=[est]
# for i in range(9):
#     est += 50
#     estimators.append(est)
#     rf.set_params(n_estimators=est)
#     rf.fit(X, y)
#     oob_scores[est] = rf.oob_score_

# %% [raw]
# oob_scores

# %% [raw]
# params_rf={'min_weight_fraction_leaf':[0.0, 0.0025, 0.005, 0.0075, 0.01, 0.05]
#            ,'min_samples_split': [0.01, 0.02, 0.03, 0.04, 0.06, 0.08, 0.1]
#            ,'min_samples_leaf':[1,2,4,6,8,10,20,30]
#            ,'min_impurity_decrease':[0.0, 0.01, 0.05, 0.10, 0.15, 0.2]
#            ,'max_leaf_nodes':[10, 15, 20, 25, 30, 35, 40, 45, 50, None]
#            ,'max_features':[0.8, 0.7, 0.6, 0.5, 0.4]
#            ,'max_depth':[None,2,4,6,8,10,20]}

# %% [raw]
# bayes_search_rf = BayesSearchCV(random_forest,params_rf,n_jobs=-1)

# %% [raw]
# bayes_search_rf.fit(X,y)

# %% [raw]
# bayes_search_rf.best_estimator_

# %% [raw]
# params_rf={'min_weight_fraction_leaf': [0.005, 0.0075, 0.01]
#            ,'min_samples_split': [1, 0.001 ,0.01, 0.02]
#            ,'min_samples_leaf':[6,7,8,9,10]
#            # ,'min_impurity_decrease':[0.0, 0.01, 0.05, 0.10, 0.15, 0.2]
#            # ,'max_leaf_nodes':[10, 15, 20, 25, 30, 35, 40, 45, 50, None]
#            ,'max_features':[0.55, 0.6, 0.65]
#            ,'max_depth':[10,20,50,100]}
# bayes_search_rf = BayesSearchCV(random_forest,params_rf,n_jobs=-1)

# %% [raw]
# bayes_search_rf.fit(X,y)
# bayes_search_rf.best_estimator_

# %%
random_forest = RandomForestRegressor(max_depth=20, max_features=0.55, min_samples_leaf=6,
                      min_samples_split=0.001, min_weight_fraction_leaf=0.005,
                      n_estimators=200, oob_score=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12704\712683234.py in <module>
# ----> 1 random_forest = RandomForestRegressor(max_depth=20, max_features=0.55, min_samples_leaf=6,
#       2                       min_samples_split=0.001, min_weight_fraction_leaf=0.005,
#       3                       n_estimators=200, oob_score=True)
#
# NameError: name 'RandomForestRegressor' is not defined

# %% [raw]
# random_forest_pipeline = make_pipeline(StandardScaler(),random_forest)

# %% [raw]
# random_forest.fit(X,y)

# %% [markdown]
# ## Adaboost

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
adaboost = AdaBoostRegressor()

# %%
adaboost_pipeline = make_pipeline(LogStandardScaler(),adaboost)

# %%
adaboost_pipeline.fit(X,y)
# Out:
# Pipeline(steps=[('logstandardscaler', LogStandardScaler()),
#                 ('adaboostregressor', AdaBoostRegressor())])

# %% [markdown]
# ## Light GBM

# %%
from lightgbm import LGBMRegressor

# %%
light_gbm = LGBMRegressor()

light_gbm_pipeline = make_pipeline(LogStandardScaler(),light_gbm)

light_gbm_pipeline.fit(X,y)
# Out:
# Pipeline(steps=[('logstandardscaler', LogStandardScaler()),
#                 ('lgbmregressor', LGBMRegressor())])

# %% [markdown]
# ## GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor()

gbr_pipeline = make_pipeline(LogStandardScaler(),gbr)

gbr.fit(X,y)
# Out:
# GradientBoostingRegressor()

# %% [markdown]
# ## Stochastic Gradient Descent Regression

# %%
from sklearn.linear_model import SGDRegressor

# %%
SGDR = SGDRegressor()

SGDR_pipeline = make_pipeline(LogStandardScaler(),SGDR)

SGDR_pipeline.fit(X,y)
# Out:
# Pipeline(steps=[('logstandardscaler', LogStandardScaler()),
#                 ('sgdregressor', SGDRegressor())])

# %% [markdown]
# ## from sklearn.svm import SVR
# Support Vector Machine

# %%
from sklearn.svm import SVR

# %%
svr = SVR()

svr_pipeline = make_pipeline(LogStandardScaler(),svr)

svr_pipeline.fit(X,y)
# Out:
# Pipeline(steps=[('logstandardscaler', LogStandardScaler()), ('svr', SVR())])

# %% [markdown]
# ## from sklearn.linear_model import BayesianRidge

# %%
from sklearn.linear_model import BayesianRidge

# %%
bayesianr = BayesianRidge()

bayesianr_pipeline = make_pipeline(LogStandardScaler(),bayesianr)

bayesianr_pipeline.fit(X,y)
# Out:
# Pipeline(steps=[('logstandardscaler', LogStandardScaler()),
#                 ('bayesianridge', BayesianRidge())])

# %% [markdown]
# ## from sklearn.kernel_ridge import KernelRidge

# %%
from sklearn.kernel_ridge import KernelRidge

# %%
kernelr = KernelRidge()

kernelr_pipeline = make_pipeline(LogStandardScaler(),kernelr)

kernelr_pipeline.fit(X,y)
# Out:
# Pipeline(steps=[('logstandardscaler', LogStandardScaler()),
#                 ('kernelridge', KernelRidge())])

# %% [markdown]
# ## Ensemble

# %%
from sklearn.ensemble import VotingRegressor, StackingRegressor

# %%
voting_reg = VotingRegressor([('elastic_net',elastic_net_pipeline)
                              ,('rf',random_forest_pipeline)
                              ,('xg_boost',xg_boost_pipeline)
                             # ,('adaboost',adaboost_pipeline)
                                  ,('lightgbm',light_gbm_pipeline)
                                  ,('gbr',gbr_pipeline)
                                  ,('bayesianRidge',bayesianr_pipeline)
                                  # ,('kernelRidge',kernelr)
                             ])

# %%
voting_reg.fit(X,y)
# Out:
# VotingRegressor(estimators=[('elastic_net',
#                              Pipeline(steps=[('logstandardscaler',
#                                               LogStandardScaler()),
#                                              ('elasticnetcv',
#                                               ElasticNetCV(cv=5,
#                                                            l1_ratio=[0.5, 0.7,
#                                                                      0.8, 0.9,
#                                                                      1],
#                                                            max_iter=2000,
#                                                            random_state=0))])),
#                             ('rf',
#                              Pipeline(steps=[('logstandardscaler',
#                                               LogStandardScaler()),
#                                              ('randomforestregressor',
#                                               RandomForestRegressor(n_estimators=200,
#                                                                     oob_score=True))])),
#                             ('xg...
#                                                            reg_lambda=1, ...))])),
#                             ('lightgbm',
#                              Pipeline(steps=[('logstandardscaler',
#                                               LogStandardScaler()),
#                                              ('lgbmregressor',
#                                               LGBMRegressor())])),
#                             ('gbr',
#                              Pipeline(steps=[('logstandardscaler',
#                                               LogStandardScaler()),
#                                              ('gradientboostingregressor',
#                                               GradientBoostingRegressor())])),
#                             ('bayesianRidge',
#                              Pipeline(steps=[('logstandardscaler',
#                                               LogStandardScaler()),
#                                              ('bayesianridge',
#                                               BayesianRidge())]))])

# %%
stacking_reg = StackingRegressor([('elastic_net',elastic_net_pipeline)
                              ,('rf',random_forest_pipeline)
                              ,('xg_boost',xg_boost_pipeline)
                             # ,('adaboost',adaboost_pipeline)
                                  ,('lightgbm',light_gbm_pipeline)
                                  ,('gbr',gbr_pipeline)
                                  ,('bayesianRidge',bayesianr_pipeline)
                                  # ,('kernelRidge',kernelr)
                             ])

# %%
stacking_reg.fit(X,y)
# Out:
# StackingRegressor(estimators=[('elastic_net',
#                                Pipeline(steps=[('logstandardscaler',
#                                                 LogStandardScaler()),
#                                                ('elasticnetcv',
#                                                 ElasticNetCV(cv=5,
#                                                              l1_ratio=[0.5, 0.7,
#                                                                        0.8, 0.9,
#                                                                        1],
#                                                              max_iter=2000,
#                                                              random_state=0))])),
#                               ('rf',
#                                Pipeline(steps=[('logstandardscaler',
#                                                 LogStandardScaler()),
#                                                ('randomforestregressor',
#                                                 RandomForestRegressor(n_estimators=200,
#                                                                       oob_score=True))])),
#                               ('...
#                                                              reg_lambda=1, ...))])),
#                               ('lightgbm',
#                                Pipeline(steps=[('logstandardscaler',
#                                                 LogStandardScaler()),
#                                                ('lgbmregressor',
#                                                 LGBMRegressor())])),
#                               ('gbr',
#                                Pipeline(steps=[('logstandardscaler',
#                                                 LogStandardScaler()),
#                                                ('gradientboostingregressor',
#                                                 GradientBoostingRegressor())])),
#                               ('bayesianRidge',
#                                Pipeline(steps=[('logstandardscaler',
#                                                 LogStandardScaler()),
#                                                ('bayesianridge',
#                                                 BayesianRidge())]))])

# %% [markdown]
# ## Cross Val Score

# %%
val_results = cross_validate(elastic_net_pipeline,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0 -0.015875  0.003899 -0.020499 -0.018528 -0.015914 -0.013897 -0.010538

# %%
val_results = cross_validate(lasso_pipeline,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count     mean       std       min       25%       50%       75%       max
# 0    5.0 -0.01589  0.003869 -0.020443 -0.018527 -0.015996 -0.013912 -0.010574

# %%
val_results = cross_validate(decision_tree_pipeline,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count      mean      std       min       25%       50%       75%     max
# 0    5.0 -0.037435  0.00513 -0.042783 -0.040168 -0.039812 -0.034313 -0.0301

# %%
val_results = cross_validate(xg_boost_pipeline,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count      mean       std       min       25%       50%       75%      max
# 0    5.0 -0.020749  0.002079 -0.024063 -0.021163 -0.020198 -0.019794 -0.01853

# %%
val_results = cross_validate(random_forest_pipeline,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count     mean       std       min       25%       50%       75%       max
# 0    5.0 -0.02076  0.002691 -0.024336 -0.022615 -0.020308 -0.018525 -0.018014

# %%
val_results = cross_validate(random_forest_initial,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count      mean       std       min       25%       50%      75%       max
# 0    5.0 -0.020326  0.002785 -0.023262 -0.022594 -0.020544 -0.01874 -0.016492

# %%
val_results = cross_validate(adaboost_pipeline,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0 -0.031226  0.003267 -0.034848 -0.033666 -0.030606 -0.030557 -0.026451

# %%
val_results = cross_validate(light_gbm_pipeline,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count      mean       std       min      25%       50%       75%       max
# 0    5.0 -0.017907  0.002759 -0.022168 -0.01865 -0.017702 -0.015801 -0.015214

# %%
val_results = cross_validate(gbr_pipeline,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0 -0.016872  0.002406 -0.020477 -0.016831 -0.016738 -0.016614 -0.013699

# %%
val_results = cross_validate(SGDR,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count          mean           std           min           25%  \
# 0    5.0 -1.904125e+33  1.031940e+33 -3.698560e+33 -1.823122e+33
#
#             50%           75%           max
# 0 -1.471204e+33 -1.377371e+33 -1.150367e+33

# %%
val_results = cross_validate(svr,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0 -0.041612  0.004728 -0.045493 -0.045119 -0.042029 -0.041672 -0.033746

# %%
val_results = cross_validate(bayesianr_pipeline,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count      mean      std       min      25%       50%      75%       max
# 0    5.0 -0.017763  0.00435 -0.022834 -0.02048 -0.018978 -0.01382 -0.012706

# %%
val_results = cross_validate(kernelr_pipeline,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count        mean       std         min         25%         50%  \
# 0    5.0 -577.065057  0.720064 -577.531635 -577.427471 -577.374909
#
#           75%         max
# 0 -577.195793 -575.795477

# %%
val_results = cross_validate(voting_reg,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0 -0.014984  0.002678 -0.018672 -0.016118 -0.015262 -0.013029 -0.011838

# %%
val_results = cross_validate(stacking_reg,X,y, scoring=['neg_mean_squared_error','r2'])
pd.DataFrame(val_results['test_neg_mean_squared_error']).describe().transpose()
# Out:
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0 -0.015611  0.003662 -0.019202 -0.019197 -0.015881 -0.012115 -0.011662

# %% [markdown]
# Scaling seems to have really benefitted the linear regression Elastic Net, but did not affect the tree based formulas much.
#
# Somehow kernalr is much worse now.

# %% [markdown]
# # Prediction

# %%
df_predict_raw = pd.read_csv('test.csv')

# %%
df_predict = df_predict_raw.copy()

# %%
df_predict['AgeHouseAtSale'] = df_predict['YrSold'] - df_predict['YearBuilt']

df_predict['YearsLastRemodelAtSale']  = df_predict['YrSold'] - df_predict['YearRemodAdd']

df_predict['YearsGarageBuiltAtSale'] = df_predict['YrSold'] - df_predict['GarageYrBlt'] 

df_predict.drop(columns=['Id'],inplace=True)

df_predict['MSSubClass'] = df_predict['MSSubClass'].astype(str)

# %%
df_predict['YearsLastRemodelAtSale'] = np.maximum(df_predict['YearsLastRemodelAtSale'],0)
df_predict['AgeHouseAtSale'] = np.maximum(df_predict['AgeHouseAtSale'],0)
df_predict['YearsGarageBuiltAtSale'] = np.maximum(df_predict['YearsGarageBuiltAtSale'],0)

# %%
for var in df_predict.dtypes[df_predict.dtypes == 'int64'].index:
    if df_predict[var].isnull().sum()>0:
        df_predict[var+'_isnull'] = df_predict[var].isnull().astype(int)
        df_predict[var]=df_predict[var].fillna(df_predict[var].mean())

for var in df_predict.dtypes[df_predict.dtypes == 'float64'].index:
    if df_predict[var].isnull().sum()>0:
        df_predict[var+'_isnull'] = df_predict[var].isnull().astype(int)
        df_predict[var]=df_predict[var].fillna(df_predict[var].mean())

df_predict_dummies = pd.get_dummies(df_predict,dummy_na=True,drop_first=False)

# %%
_, df_predict_dummies = X.align(df_predict_dummies, axis=1, fill_value=0)

# %%
df_predict_dummies.drop(columns=df_predict_dummies.columns[~df_predict_dummies.columns.isin(X.columns)],inplace=True)

# %%
df_predict_dummies['intercept']=1

# %%
df_predict_dummies.describe()
# Out:
#           1stFlrSF     2ndFlrSF    3SsnPorch  AgeHouseAtSale   Alley_Grvl  \
# count  1459.000000  1459.000000  1459.000000     1459.000000  1459.000000
# mean   1156.534613   325.967786     1.794380       36.412611     0.047978
# std     398.165820   420.610226    20.207842       30.431416     0.213793
# min     407.000000     0.000000     0.000000        0.000000     0.000000
# 25%     873.500000     0.000000     0.000000        7.000000     0.000000
# 50%    1079.000000     0.000000     0.000000       34.000000     0.000000
# 75%    1382.500000   676.000000     0.000000       55.000000     0.000000
# max    5095.000000  1862.000000   360.000000      129.000000     1.000000
#
#         Alley_Pave    Alley_nan  BedroomAbvGr  BldgType_1Fam  BldgType_2fmCon  \
# count  1459.000000  1459.000000   1459.000000    1459.000000      1459.000000
# mean      0.025360     0.926662      2.854010       0.825908         0.021247
# std       0.157269     0.260780      0.829788       0.379318         0.144258
# min       0.000000     0.000000      0.000000       0.000000         0.000000
# 25%       0.000000     1.000000      2.000000       1.000000         0.000000
# 50%       0.000000     1.000000      3.000000       1.000000         0.000000
# 75%       0.000000     1.000000      3.000000       1.000000         0.000000
# max       1.000000     1.000000      6.000000       1.000000         1.000000
#
#        BldgType_Duplex  BldgType_Twnhs  BldgType_TwnhsE  BsmtCond_Fa  \
# count      1459.000000     1459.000000      1459.000000  1459.000000
# mean          0.039068        0.036326         0.077450     0.040439
# std           0.193823        0.187165         0.267396     0.197053
# min           0.000000        0.000000         0.000000     0.000000
# 25%           0.000000        0.000000         0.000000     0.000000
# 50%           0.000000        0.000000         0.000000     0.000000
# 75%           0.000000        0.000000         0.000000     0.000000
# max           1.000000        1.000000         1.000000     1.000000
#
#        BsmtCond_Gd  BsmtCond_Po  BsmtCond_TA  BsmtCond_nan  BsmtExposure_Av  \
# count  1459.000000  1459.000000  1459.000000   1459.000000      1459.000000
# mean      0.039068     0.002056     0.887594      0.030843         0.135024
# std       0.193823     0.045314     0.315973      0.172952         0.341866
# min       0.000000     0.000000     0.000000      0.000000         0.000000
# 25%       0.000000     0.000000     1.000000      0.000000         0.000000
# 50%       0.000000     0.000000     1.000000      0.000000         0.000000
# 75%       0.000000     0.000000     1.000000      0.000000         0.000000
# max       1.000000     1.000000     1.000000      1.000000         1.000000
#
#        BsmtExposure_Gd  BsmtExposure_Mn  BsmtExposure_No  BsmtExposure_nan  \
# count      1459.000000      1459.000000      1459.000000       1459.000000
# mean          0.097327         0.085675         0.651816          0.030158
# std           0.296504         0.279980         0.476558          0.171080
# min           0.000000         0.000000         0.000000          0.000000
# 25%           0.000000         0.000000         0.000000          0.000000
# 50%           0.000000         0.000000         1.000000          0.000000
# 75%           0.000000         0.000000         1.000000          0.000000
# max           1.000000         1.000000         1.000000          1.000000
#
#         BsmtFinSF1   BsmtFinSF2  BsmtFinType1_ALQ  BsmtFinType1_BLQ  \
# count  1459.000000  1459.000000       1459.000000       1459.000000
# mean    439.203704    52.619342          0.143249          0.082934
# std     455.111888   176.693301          0.350447          0.275876
# min       0.000000     0.000000          0.000000          0.000000
# 25%       0.000000     0.000000          0.000000          0.000000
# 50%     351.000000     0.000000          0.000000          0.000000
# 75%     752.000000     0.000000          0.000000          0.000000
# max    4010.000000  1526.000000          1.000000          1.000000
#
#        BsmtFinType1_GLQ  BsmtFinType1_LwQ  BsmtFinType1_Rec  BsmtFinType1_Unf  \
# count       1459.000000       1459.000000       1459.000000       1459.000000
# mean           0.295408          0.054832          0.106237          0.288554
# std            0.456382          0.227730          0.308247          0.453245
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000          0.000000
# 75%            1.000000          0.000000          0.000000          1.000000
# max            1.000000          1.000000          1.000000          1.000000
#
#        BsmtFinType1_nan  BsmtFinType2_ALQ  BsmtFinType2_BLQ  BsmtFinType2_GLQ  \
# count       1459.000000       1459.000000       1459.000000       1459.000000
# mean           0.028787          0.022618          0.023989          0.013708
# std            0.167264          0.148734          0.153067          0.116316
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000          0.000000
# 75%            0.000000          0.000000          0.000000          0.000000
# max            1.000000          1.000000          1.000000          1.000000
#
#        BsmtFinType2_LwQ  BsmtFinType2_Rec  BsmtFinType2_Unf  BsmtFinType2_nan  \
# count       1459.000000       1459.000000       1459.000000       1459.000000
# mean           0.028101          0.034955          0.847841          0.028787
# std            0.165319          0.183730          0.359298          0.167264
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          1.000000          0.000000
# 50%            0.000000          0.000000          1.000000          0.000000
# 75%            0.000000          0.000000          1.000000          0.000000
# max            1.000000          1.000000          1.000000          1.000000
#
#        BsmtFullBath  BsmtHalfBath  BsmtQual_Ex  BsmtQual_Fa  BsmtQual_Gd  \
# count   1459.000000   1459.000000  1459.000000  1459.000000  1459.000000
# mean       0.434454      0.065202     0.093900     0.036326     0.405072
# std        0.530283      0.252295     0.291789     0.187165     0.491074
# min        0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        0.000000      0.000000     0.000000     0.000000     0.000000
# 50%        0.000000      0.000000     0.000000     0.000000     0.000000
# 75%        1.000000      0.000000     0.000000     0.000000     1.000000
# max        3.000000      2.000000     1.000000     1.000000     1.000000
#
#        BsmtQual_TA  BsmtQual_nan    BsmtUnfSF  CentralAir_N  CentralAir_Y  \
# count  1459.000000   1459.000000  1459.000000   1459.000000   1459.000000
# mean      0.434544      0.030158   554.294925      0.069225      0.930775
# std       0.495867      0.171080   437.110508      0.253924      0.253924
# min       0.000000      0.000000     0.000000      0.000000      0.000000
# 25%       0.000000      0.000000   219.500000      0.000000      1.000000
# 50%       0.000000      0.000000   460.000000      0.000000      1.000000
# 75%       1.000000      0.000000   797.500000      0.000000      1.000000
# max       1.000000      1.000000  2140.000000      1.000000      1.000000
#
#        Condition1_Artery  ...  PavedDrive_Y     PoolArea    PoolQC_Ex  \
# count        1459.000000  ...   1459.000000  1459.000000  1459.000000
# mean            0.030158  ...      0.891707     1.744345     0.001371
# std             0.171080  ...      0.310857    30.491646     0.037012
# min             0.000000  ...      0.000000     0.000000     0.000000
# 25%             0.000000  ...      1.000000     0.000000     0.000000
# 50%             0.000000  ...      1.000000     0.000000     0.000000
# 75%             0.000000  ...      1.000000     0.000000     0.000000
# max             1.000000  ...      1.000000   800.000000     1.000000
#
#        PoolQC_Fa    PoolQC_Gd   PoolQC_nan  RoofMatl_ClyTile  \
# count     1459.0  1459.000000  1459.000000            1459.0
# mean         0.0     0.000685     0.997944               0.0
# std          0.0     0.026180     0.045314               0.0
# min          0.0     0.000000     0.000000               0.0
# 25%          0.0     0.000000     1.000000               0.0
# 50%          0.0     0.000000     1.000000               0.0
# 75%          0.0     0.000000     1.000000               0.0
# max          0.0     1.000000     1.000000               0.0
#
#        RoofMatl_CompShg  RoofMatl_Membran  RoofMatl_Metal  RoofMatl_Roll  \
# count       1459.000000            1459.0          1459.0         1459.0
# mean           0.988348               0.0             0.0            0.0
# std            0.107350               0.0             0.0            0.0
# min            0.000000               0.0             0.0            0.0
# 25%            1.000000               0.0             0.0            0.0
# 50%            1.000000               0.0             0.0            0.0
# 75%            1.000000               0.0             0.0            0.0
# max            1.000000               0.0             0.0            0.0
#
#        RoofMatl_Tar&Grv  RoofMatl_WdShake  RoofMatl_WdShngl  RoofStyle_Flat  \
# count       1459.000000       1459.000000       1459.000000     1459.000000
# mean           0.008225          0.002742          0.000685        0.004798
# std            0.090348          0.052306          0.026180        0.069124
# min            0.000000          0.000000          0.000000        0.000000
# 25%            0.000000          0.000000          0.000000        0.000000
# 50%            0.000000          0.000000          0.000000        0.000000
# 75%            0.000000          0.000000          0.000000        0.000000
# max            1.000000          1.000000          1.000000        1.000000
#
#        RoofStyle_Gable  RoofStyle_Gambrel  RoofStyle_Hip  RoofStyle_Mansard  \
# count      1459.000000        1459.000000    1459.000000        1459.000000
# mean          0.801234           0.007539       0.181631           0.002742
# std           0.399209           0.086531       0.385673           0.052306
# min           0.000000           0.000000       0.000000           0.000000
# 25%           1.000000           0.000000       0.000000           0.000000
# 50%           1.000000           0.000000       0.000000           0.000000
# 75%           1.000000           0.000000       0.000000           0.000000
# max           1.000000           1.000000       1.000000           1.000000
#
#        RoofStyle_Shed  SaleCondition_Abnorml  SaleCondition_AdjLand  \
# count     1459.000000            1459.000000            1459.000000
# mean         0.002056               0.061001               0.005483
# std          0.045314               0.239414               0.073871
# min          0.000000               0.000000               0.000000
# 25%          0.000000               0.000000               0.000000
# 50%          0.000000               0.000000               0.000000
# 75%          0.000000               0.000000               0.000000
# max          1.000000               1.000000               1.000000
#
#        SaleCondition_Alloca  SaleCondition_Family  SaleCondition_Normal  \
# count           1459.000000           1459.000000           1459.000000
# mean               0.008225              0.017820              0.825223
# std                0.090348              0.132344              0.379907
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              1.000000
# 50%                0.000000              0.000000              1.000000
# 75%                0.000000              0.000000              1.000000
# max                1.000000              1.000000              1.000000
#
#        SaleCondition_Partial  SaleType_COD  SaleType_CWD  SaleType_Con  \
# count            1459.000000   1459.000000   1459.000000   1459.000000
# mean                0.082248      0.030158      0.005483      0.002056
# std                 0.274837      0.171080      0.073871      0.045314
# min                 0.000000      0.000000      0.000000      0.000000
# 25%                 0.000000      0.000000      0.000000      0.000000
# 50%                 0.000000      0.000000      0.000000      0.000000
# 75%                 0.000000      0.000000      0.000000      0.000000
# max                 1.000000      1.000000      1.000000      1.000000
#
#        SaleType_ConLD  SaleType_ConLI  SaleType_ConLw  SaleType_New  \
# count     1459.000000     1459.000000     1459.000000   1459.000000
# mean         0.011652        0.002742        0.002056      0.080192
# std          0.107350        0.052306        0.045314      0.271683
# min          0.000000        0.000000        0.000000      0.000000
# 25%          0.000000        0.000000        0.000000      0.000000
# 50%          0.000000        0.000000        0.000000      0.000000
# 75%          0.000000        0.000000        0.000000      0.000000
# max          1.000000        1.000000        1.000000      1.000000
#
#        SaleType_Oth  SaleType_WD  ScreenPorch  Street_Grvl  Street_Pave  \
# count   1459.000000  1459.000000  1459.000000  1459.000000  1459.000000
# mean       0.002742     0.862234    17.064428     0.004112     0.995888
# std        0.052306     0.344772    56.609763     0.064018     0.064018
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%        0.000000     1.000000     0.000000     0.000000     1.000000
# 50%        0.000000     1.000000     0.000000     0.000000     1.000000
# 75%        0.000000     1.000000     0.000000     0.000000     1.000000
# max        1.000000     1.000000   576.000000     1.000000     1.000000
#
#        TotRmsAbvGrd  TotalBsmtSF  Utilities_AllPub  Utilities_NoSeWa  \
# count   1459.000000  1459.000000       1459.000000            1459.0
# mean       6.385195  1046.117970          0.998629               0.0
# std        1.508895   442.746712          0.037012               0.0
# min        3.000000     0.000000          0.000000               0.0
# 25%        5.000000   784.000000          1.000000               0.0
# 50%        6.000000   988.000000          1.000000               0.0
# 75%        7.000000  1304.000000          1.000000               0.0
# max       15.000000  5095.000000          1.000000               0.0
#
#         WoodDeckSF    YearBuilt  YearRemodAdd  YearsGarageBuiltAtSale  \
# count  1459.000000  1459.000000   1459.000000             1459.000000
# mean     93.174777  1971.357779   1983.662783               30.191166
# std     127.744882    30.390071     21.130467               25.052613
# min       0.000000  1879.000000   1950.000000                0.000000
# 25%       0.000000  1953.000000   1963.000000                7.000000
# 50%       0.000000  1973.000000   1992.000000               30.191166
# 75%     168.000000  2001.000000   2004.000000               48.000000
# max    1424.000000  2010.000000   2010.000000              114.000000
#
#        YearsGarageBuiltAtSale_isnull  YearsLastRemodelAtSale       YrSold  \
# count                    1459.000000             1459.000000  1459.000000
# mean                        0.053461               24.108979  2007.769705
# std                         0.225029               21.129454     1.301740
# min                         0.000000                0.000000  2006.000000
# 25%                         0.000000                4.000000  2007.000000
# 50%                         0.000000               16.000000  2008.000000
# 75%                         0.000000               44.000000  2009.000000
# max                         1.000000               60.000000  2010.000000
#
#        intercept
# count     1459.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
#
# [8 rows x 326 columns]

# %% [markdown]
# ## Predictions

# %% [markdown]
# ### Statsmodel low regularization

# %%
df_predict_raw['SalePrice'] = np.exp(results.predict(df_predict_dummies[X.columns]))

df_predict_raw[['Id','SalePrice']].to_csv('predictions_initial.csv',index=False)

# %% [markdown]
# ### Elastic Net

# %%
df_predict_raw['SalePrice'] =  np.exp(elastic_net_pipeline.predict(df_predict_dummies[X.columns]))

df_predict_raw[['Id','SalePrice']].to_csv('predictions_elasticnet_log_standardized.csv',index=False)

# %% [markdown]
# ### Decision Tree

# %%
df_predict_raw['SalePrice'] =  np.exp(decision_tree_pipeline.predict(df_predict_dummies[X.columns]))

df_predict_raw[['Id','SalePrice']].to_csv('predictions_decisiontree_logstandard.csv',index=False)

# %% [markdown]
# ### XG Boost

# %%
df_predict_raw['SalePrice'] =  np.exp(xg_boost_pipeline.predict(df_predict_dummies[X.columns]))

df_predict_raw[['Id','SalePrice']].to_csv('predictions_xgboost_logstandard.csv',index=False)

# %% [markdown]
# ### Random Forest

# %%
df_predict_raw['SalePrice'] =  np.exp(random_forest.predict(df_predict_dummies[X.columns]))

df_predict_raw[['Id','SalePrice']].to_csv('predictions_rf_cv.csv',index=False)

# %%
df_predict_raw['SalePrice'] =  np.exp(random_forest_initial.predict(df_predict_dummies[X.columns]))

df_predict_raw[['Id','SalePrice']].to_csv('predictions_rf_logstandard.csv',index=False)

# %% [markdown]
# ### Light GBM

# %%
df_predict_raw['SalePrice'] =  np.exp(light_gbm.predict(df_predict_dummies[X.columns]))

df_predict_raw[['Id','SalePrice']].to_csv('predictions_light_gbm.csv',index=False)

# %% [markdown]
# ### Gradient Boosting Regression

# %%
df_predict_raw['SalePrice'] =  np.exp(gbr.predict(df_predict_dummies[X.columns]))

df_predict_raw[['Id','SalePrice']].to_csv('predictions_gbr.csv',index=False)

# %% [markdown]
# ### Voting Regression

# %%
df_predict_raw['SalePrice'] =  np.exp(voting_reg.predict(df_predict_dummies[X.columns]))

df_predict_raw[['Id','SalePrice']].to_csv('predictions_voting_reg_standardized.csv',index=False)

# %% [markdown]
# ### Stacking Regression

# %%
df_predict_raw['SalePrice'] =  np.exp(stacking_reg.predict(df_predict_dummies[X.columns]))

df_predict_raw[['Id','SalePrice']].to_csv('predictions_stacking_reg.csv',index=False)
